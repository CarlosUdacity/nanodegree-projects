# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/cifar/cifar-10-python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# CIFAR-10 Dataset: 171MB [00:27, 6.09MB/s]
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# /usr/local/lib/python3.5/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # Implement Function
    x_min = x.min()
    x_max = x.max()
    a = 0
    b = 1
    x_prime = a + (x - x_min) * (b - a) / (x_max - x_min)
    return x_prime


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
from sklearn.preprocessing import LabelBinarizer

encoder = LabelBinarizer()
encoder_fit = False

def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    y = np.eye(10)[x]
    return y


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # Implement Function
    return tf.placeholder(tf.float32, 
                          shape=[None, image_shape[0], image_shape[1], image_shape[2]],
                          name='x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # Implement Function
    return tf.placeholder(tf.float32,
                         shape=[None, n_classes],
                         name='y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # Implement Function
    return tf.placeholder(tf.float32, name='keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # Implement Function
    # 2x2 conv, 5 inputs, 32 outputs
    #print(x_tensor.shape, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    W = tf.Variable(tf.random_normal([conv_ksize[0], conv_ksize[1], x_tensor.shape.as_list()[-1], conv_num_outputs], stddev=0.05))
    b = tf.Variable(tf.random_normal([conv_num_outputs]))
    
    x = tf.nn.conv2d(x_tensor, W, strides=[1, conv_strides[0], conv_strides[1], 1], padding='SAME')
    x = tf.nn.bias_add(x, b)
    x = tf.nn.relu(x)
    return tf.nn.max_pool(x, ksize=[1, pool_ksize[0], pool_ksize[1], 1], 
                          strides=[1, pool_strides[0], pool_strides[1], 1], padding='SAME')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # Implement Function
    return tf.contrib.layers.flatten(x_tensor)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Implement Function
    return tf.contrib.layers.fully_connected(x_tensor, num_outputs)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # Implement Function
    W = tf.Variable(tf.random_normal([x_tensor.shape.as_list()[-1], num_outputs], stddev=0.05))
    b = tf.Variable(tf.random_normal([num_outputs]))
    return tf.add(tf.matmul(x_tensor, W), b)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    
    out = conv2d_maxpool(x, 64, (5, 5), (2, 2), (2, 2), (2, 2))
    out = conv2d_maxpool(out, 128, (5, 5), (2, 2), (2, 2), (2, 2))
    
    # Apply a Flatten Layer
    # Function Definition from Above:
    out = flatten(out)

    # Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    out = fully_conn(out, 1024)
    out = tf.nn.dropout(out, keep_prob)
    out = fully_conn(out, 512)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    out = output(out, 10)
    
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # Implement Function
    session.run(optimizer, feed_dict={x: feature_batch, y: label_batch, keep_prob: keep_probability}) 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # Implement Function
    loss = session.run(cost, feed_dict={x: feature_batch, y: label_batch, keep_prob: 1.0}) 
    acc = session.run(accuracy, feed_dict={x: valid_features, y: valid_labels, keep_prob: 1.0})
    print("Loss= " + "{:.4f}".format(loss) + ", Accuracy= " + "{:.4f}".format(acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# Tune Parameters
epochs = 100
batch_size = 512
keep_probability = 0.75

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  Loss= 2.2780, Accuracy= 0.1260
# Epoch  2, CIFAR-10 Batch 1:  Loss= 2.1355, Accuracy= 0.2498
# Epoch  3, CIFAR-10 Batch 1:  Loss= 2.0073, Accuracy= 0.2624
# Epoch  4, CIFAR-10 Batch 1:  Loss= 1.8725, Accuracy= 0.3534
# Epoch  5, CIFAR-10 Batch 1:  Loss= 1.8150, Accuracy= 0.3722
# Epoch  6, CIFAR-10 Batch 1:  Loss= 1.7345, Accuracy= 0.3868
# Epoch  7, CIFAR-10 Batch 1:  Loss= 1.6469, Accuracy= 0.4002
# Epoch  8, CIFAR-10 Batch 1:  Loss= 1.5812, Accuracy= 0.4244
# Epoch  9, CIFAR-10 Batch 1:  Loss= 1.5505, Accuracy= 0.4252
# Epoch 10, CIFAR-10 Batch 1:  Loss= 1.5044, Accuracy= 0.4260
# Epoch 11, CIFAR-10 Batch 1:  Loss= 1.4579, Accuracy= 0.4362
# Epoch 12, CIFAR-10 Batch 1:  Loss= 1.3680, Accuracy= 0.4594
# Epoch 13, CIFAR-10 Batch 1:  Loss= 1.3022, Accuracy= 0.4702
# Epoch 14, CIFAR-10 Batch 1:  Loss= 1.2555, Accuracy= 0.4750
# Epoch 15, CIFAR-10 Batch 1:  Loss= 1.2371, Accuracy= 0.4756
# Epoch 16, CIFAR-10 Batch 1:  Loss= 1.1999, Accuracy= 0.4808
# Epoch 17, CIFAR-10 Batch 1:  Loss= 1.1607, Accuracy= 0.4994
# Epoch 18, CIFAR-10 Batch 1:  Loss= 1.0824, Accuracy= 0.5084
# Epoch 19, CIFAR-10 Batch 1:  Loss= 1.0455, Accuracy= 0.5080
# Epoch 20, CIFAR-10 Batch 1:  Loss= 0.9859, Accuracy= 0.5104
# Epoch 21, CIFAR-10 Batch 1:  Loss= 0.9397, Accuracy= 0.5108
# Epoch 22, CIFAR-10 Batch 1:  Loss= 0.8843, Accuracy= 0.5142
# Epoch 23, CIFAR-10 Batch 1:  Loss= 0.8336, Accuracy= 0.5192
# Epoch 24, CIFAR-10 Batch 1:  Loss= 0.7940, Accuracy= 0.5214
# Epoch 25, CIFAR-10 Batch 1:  Loss= 0.7779, Accuracy= 0.5104
# Epoch 26, CIFAR-10 Batch 1:  Loss= 0.7386, Accuracy= 0.5122
# Epoch 27, CIFAR-10 Batch 1:  Loss= 0.7276, Accuracy= 0.5010
# Epoch 28, CIFAR-10 Batch 1:  Loss= 0.6630, Accuracy= 0.5194
# Epoch 29, CIFAR-10 Batch 1:  Loss= 0.5955, Accuracy= 0.5226
# Epoch 30, CIFAR-10 Batch 1:  Loss= 0.5528, Accuracy= 0.5126
# Epoch 31, CIFAR-10 Batch 1:  Loss= 0.4953, Accuracy= 0.5274
# Epoch 32, CIFAR-10 Batch 1:  Loss= 0.4996, Accuracy= 0.5280
# Epoch 33, CIFAR-10 Batch 1:  Loss= 0.5562, Accuracy= 0.5068
# Epoch 34, CIFAR-10 Batch 1:  Loss= 0.4601, Accuracy= 0.5136
# Epoch 35, CIFAR-10 Batch 1:  Loss= 0.4312, Accuracy= 0.5152
# Epoch 36, CIFAR-10 Batch 1:  Loss= 0.4163, Accuracy= 0.5156
# Epoch 37, CIFAR-10 Batch 1:  Loss= 0.3740, Accuracy= 0.5140
# Epoch 38, CIFAR-10 Batch 1:  Loss= 0.3320, Accuracy= 0.5322
# Epoch 39, CIFAR-10 Batch 1:  Loss= 0.3213, Accuracy= 0.5206
# Epoch 40, CIFAR-10 Batch 1:  Loss= 0.3422, Accuracy= 0.5182
# Epoch 41, CIFAR-10 Batch 1:  Loss= 0.3386, Accuracy= 0.5180
# Epoch 42, CIFAR-10 Batch 1:  Loss= 0.3247, Accuracy= 0.5000
# Epoch 43, CIFAR-10 Batch 1:  Loss= 0.3171, Accuracy= 0.5140
# Epoch 44, CIFAR-10 Batch 1:  Loss= 0.2820, Accuracy= 0.5126
# Epoch 45, CIFAR-10 Batch 1:  Loss= 0.2205, Accuracy= 0.5196
# Epoch 46, CIFAR-10 Batch 1:  Loss= 0.1878, Accuracy= 0.5210
# Epoch 47, CIFAR-10 Batch 1:  Loss= 0.1923, Accuracy= 0.5074
# Epoch 48, CIFAR-10 Batch 1:  Loss= 0.1798, Accuracy= 0.5060
# Epoch 49, CIFAR-10 Batch 1:  Loss= 0.1945, Accuracy= 0.5016
# Epoch 50, CIFAR-10 Batch 1:  Loss= 0.1773, Accuracy= 0.5060
# Epoch 51, CIFAR-10 Batch 1:  Loss= 0.1913, Accuracy= 0.5162
# Epoch 52, CIFAR-10 Batch 1:  Loss= 0.1663, Accuracy= 0.4968
# Epoch 53, CIFAR-10 Batch 1:  Loss= 0.1314, Accuracy= 0.5122
# Epoch 54, CIFAR-10 Batch 1:  Loss= 0.1222, Accuracy= 0.5036
# Epoch 55, CIFAR-10 Batch 1:  Loss= 0.1019, Accuracy= 0.4956
# Epoch 56, CIFAR-10 Batch 1:  Loss= 0.1049, Accuracy= 0.5078
# Epoch 57, CIFAR-10 Batch 1:  Loss= 0.1897, Accuracy= 0.4774
# Epoch 58, CIFAR-10 Batch 1:  Loss= 0.1097, Accuracy= 0.5052
# Epoch 59, CIFAR-10 Batch 1:  Loss= 0.0974, Accuracy= 0.5064
# Epoch 60, CIFAR-10 Batch 1:  Loss= 0.0849, Accuracy= 0.5122
# Epoch 61, CIFAR-10 Batch 1:  Loss= 0.0861, Accuracy= 0.5100
# Epoch 62, CIFAR-10 Batch 1:  Loss= 0.0527, Accuracy= 0.5116
# Epoch 63, CIFAR-10 Batch 1:  Loss= 0.0489, Accuracy= 0.5268
# Epoch 64, CIFAR-10 Batch 1:  Loss= 0.0818, Accuracy= 0.5146
# Epoch 65, CIFAR-10 Batch 1:  Loss= 0.0509, Accuracy= 0.5210
# Epoch 66, CIFAR-10 Batch 1:  Loss= 0.0379, Accuracy= 0.5170
# Epoch 67, CIFAR-10 Batch 1:  Loss= 0.0550, Accuracy= 0.5160
# Epoch 68, CIFAR-10 Batch 1:  Loss= 0.0382, Accuracy= 0.5110
# Epoch 69, CIFAR-10 Batch 1:  Loss= 0.0787, Accuracy= 0.5042
# Epoch 70, CIFAR-10 Batch 1:  Loss= 0.0672, Accuracy= 0.5048
# Epoch 71, CIFAR-10 Batch 1:  Loss= 0.0511, Accuracy= 0.5216
# Epoch 72, CIFAR-10 Batch 1:  Loss= 0.0252, Accuracy= 0.5186
# Epoch 73, CIFAR-10 Batch 1:  Loss= 0.0231, Accuracy= 0.5126
# Epoch 74, CIFAR-10 Batch 1:  Loss= 0.0356, Accuracy= 0.5034
# Epoch 75, CIFAR-10 Batch 1:  Loss= 0.0514, Accuracy= 0.4966
# Epoch 76, CIFAR-10 Batch 1:  Loss= 0.0379, Accuracy= 0.5032
# Epoch 77, CIFAR-10 Batch 1:  Loss= 0.0182, Accuracy= 0.5198
# Epoch 78, CIFAR-10 Batch 1:  Loss= 0.0127, Accuracy= 0.5188
# Epoch 79, CIFAR-10 Batch 1:  Loss= 0.0137, Accuracy= 0.5322
# Epoch 80, CIFAR-10 Batch 1:  Loss= 0.0100, Accuracy= 0.5288
# Epoch 81, CIFAR-10 Batch 1:  Loss= 0.0066, Accuracy= 0.5304
# Epoch 82, CIFAR-10 Batch 1:  Loss= 0.0060, Accuracy= 0.5284
# Epoch 83, CIFAR-10 Batch 1:  Loss= 0.0050, Accuracy= 0.5286
# Epoch 84, CIFAR-10 Batch 1:  Loss= 0.0040, Accuracy= 0.5326
# Epoch 85, CIFAR-10 Batch 1:  Loss= 0.0037, Accuracy= 0.5330
# Epoch 86, CIFAR-10 Batch 1:  Loss= 0.0026, Accuracy= 0.5270
# Epoch 87, CIFAR-10 Batch 1:  Loss= 0.0032, Accuracy= 0.5290
# Epoch 88, CIFAR-10 Batch 1:  Loss= 0.0026, Accuracy= 0.5348
# Epoch 89, CIFAR-10 Batch 1:  Loss= 0.0032, Accuracy= 0.5280
# Epoch 90, CIFAR-10 Batch 1:  Loss= 0.0023, Accuracy= 0.5308
# Epoch 91, CIFAR-10 Batch 1:  Loss= 0.0019, Accuracy= 0.5342
# Epoch 92, CIFAR-10 Batch 1:  Loss= 0.0022, Accuracy= 0.5254
# Epoch 93, CIFAR-10 Batch 1:  Loss= 0.0036, Accuracy= 0.5266
# Epoch 94, CIFAR-10 Batch 1:  Loss= 0.0027, Accuracy= 0.5246
# Epoch 95, CIFAR-10 Batch 1:  Loss= 0.0031, Accuracy= 0.5256
# Epoch 96, CIFAR-10 Batch 1:  Loss= 0.0040, Accuracy= 0.5226
# Epoch 97, CIFAR-10 Batch 1:  Loss= 0.0029, Accuracy= 0.5198
# Epoch 98, CIFAR-10 Batch 1:  Loss= 0.0044, Accuracy= 0.5138
# Epoch 99, CIFAR-10 Batch 1:  Loss= 0.0041, Accuracy= 0.5148
# Epoch 100, CIFAR-10 Batch 1:  Loss= 0.0058, Accuracy= 0.5194

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss= 2.3054, Accuracy= 0.1086
# Epoch  1, CIFAR-10 Batch 2:  Loss= 2.1200, Accuracy= 0.2168
# Epoch  1, CIFAR-10 Batch 3:  Loss= 2.0193, Accuracy= 0.2276
# Epoch  1, CIFAR-10 Batch 4:  Loss= 1.8600, Accuracy= 0.2888
# Epoch  1, CIFAR-10 Batch 5:  Loss= 1.8421, Accuracy= 0.3292
# Epoch  2, CIFAR-10 Batch 1:  Loss= 1.8485, Accuracy= 0.3484
# Epoch  2, CIFAR-10 Batch 2:  Loss= 1.6671, Accuracy= 0.3856
# Epoch  2, CIFAR-10 Batch 3:  Loss= 1.5496, Accuracy= 0.3734
# Epoch  2, CIFAR-10 Batch 4:  Loss= 1.4982, Accuracy= 0.4072
# Epoch  2, CIFAR-10 Batch 5:  Loss= 1.5905, Accuracy= 0.4434
# Epoch  3, CIFAR-10 Batch 1:  Loss= 1.6261, Accuracy= 0.4244
# Epoch  3, CIFAR-10 Batch 2:  Loss= 1.4966, Accuracy= 0.4438
# Epoch  3, CIFAR-10 Batch 3:  Loss= 1.3167, Accuracy= 0.4500
# Epoch  3, CIFAR-10 Batch 4:  Loss= 1.3530, Accuracy= 0.4608
# Epoch  3, CIFAR-10 Batch 5:  Loss= 1.4532, Accuracy= 0.4836
# Epoch  4, CIFAR-10 Batch 1:  Loss= 1.4875, Accuracy= 0.4894
# Epoch  4, CIFAR-10 Batch 2:  Loss= 1.3823, Accuracy= 0.4742
# Epoch  4, CIFAR-10 Batch 3:  Loss= 1.2302, Accuracy= 0.4776
# Epoch  4, CIFAR-10 Batch 4:  Loss= 1.2821, Accuracy= 0.4764
# Epoch  4, CIFAR-10 Batch 5:  Loss= 1.3455, Accuracy= 0.5008
# Epoch  5, CIFAR-10 Batch 1:  Loss= 1.3831, Accuracy= 0.5134
# Epoch  5, CIFAR-10 Batch 2:  Loss= 1.3039, Accuracy= 0.4956
# Epoch  5, CIFAR-10 Batch 3:  Loss= 1.1516, Accuracy= 0.4954
# Epoch  5, CIFAR-10 Batch 4:  Loss= 1.1845, Accuracy= 0.5186
# Epoch  5, CIFAR-10 Batch 5:  Loss= 1.2577, Accuracy= 0.5210
# Epoch  6, CIFAR-10 Batch 1:  Loss= 1.2998, Accuracy= 0.5302
# Epoch  6, CIFAR-10 Batch 2:  Loss= 1.2169, Accuracy= 0.5086
# Epoch  6, CIFAR-10 Batch 3:  Loss= 1.0946, Accuracy= 0.5178
# Epoch  6, CIFAR-10 Batch 4:  Loss= 1.0932, Accuracy= 0.5370
# Epoch  6, CIFAR-10 Batch 5:  Loss= 1.1823, Accuracy= 0.5422
# Epoch  7, CIFAR-10 Batch 1:  Loss= 1.2316, Accuracy= 0.5450
# Epoch  7, CIFAR-10 Batch 2:  Loss= 1.1365, Accuracy= 0.5340
# Epoch  7, CIFAR-10 Batch 3:  Loss= 1.0484, Accuracy= 0.5276
# Epoch  7, CIFAR-10 Batch 4:  Loss= 1.0418, Accuracy= 0.5474
# Epoch  7, CIFAR-10 Batch 5:  Loss= 1.1081, Accuracy= 0.5548
# Epoch  8, CIFAR-10 Batch 1:  Loss= 1.1777, Accuracy= 0.5482
# Epoch  8, CIFAR-10 Batch 2:  Loss= 1.1053, Accuracy= 0.5508
# Epoch  8, CIFAR-10 Batch 3:  Loss= 0.9915, Accuracy= 0.5340
# Epoch  8, CIFAR-10 Batch 4:  Loss= 1.0152, Accuracy= 0.5522
# Epoch  8, CIFAR-10 Batch 5:  Loss= 1.0488, Accuracy= 0.5678
# Epoch  9, CIFAR-10 Batch 1:  Loss= 1.1240, Accuracy= 0.5594
# Epoch  9, CIFAR-10 Batch 2:  Loss= 1.0294, Accuracy= 0.5536
# Epoch  9, CIFAR-10 Batch 3:  Loss= 0.9175, Accuracy= 0.5572
# Epoch  9, CIFAR-10 Batch 4:  Loss= 0.9287, Accuracy= 0.5712
# Epoch  9, CIFAR-10 Batch 5:  Loss= 0.9840, Accuracy= 0.5756
# Epoch 10, CIFAR-10 Batch 1:  Loss= 1.0640, Accuracy= 0.5644
# Epoch 10, CIFAR-10 Batch 2:  Loss= 0.9728, Accuracy= 0.5726
# Epoch 10, CIFAR-10 Batch 3:  Loss= 0.8721, Accuracy= 0.5654
# Epoch 10, CIFAR-10 Batch 4:  Loss= 0.8787, Accuracy= 0.5840
# Epoch 10, CIFAR-10 Batch 5:  Loss= 0.9384, Accuracy= 0.5854
# Epoch 11, CIFAR-10 Batch 1:  Loss= 1.0162, Accuracy= 0.5758
# Epoch 11, CIFAR-10 Batch 2:  Loss= 0.9320, Accuracy= 0.5808
# Epoch 11, CIFAR-10 Batch 3:  Loss= 0.8777, Accuracy= 0.5514
# Epoch 11, CIFAR-10 Batch 4:  Loss= 0.8276, Accuracy= 0.5850
# Epoch 11, CIFAR-10 Batch 5:  Loss= 0.8865, Accuracy= 0.5942
# Epoch 12, CIFAR-10 Batch 1:  Loss= 0.9705, Accuracy= 0.5804
# Epoch 12, CIFAR-10 Batch 2:  Loss= 0.8778, Accuracy= 0.5880
# Epoch 12, CIFAR-10 Batch 3:  Loss= 0.7964, Accuracy= 0.5758
# Epoch 12, CIFAR-10 Batch 4:  Loss= 0.7685, Accuracy= 0.5880
# Epoch 12, CIFAR-10 Batch 5:  Loss= 0.8188, Accuracy= 0.6002
# Epoch 13, CIFAR-10 Batch 1:  Loss= 0.9258, Accuracy= 0.5848
# Epoch 13, CIFAR-10 Batch 2:  Loss= 0.8464, Accuracy= 0.5936
# Epoch 13, CIFAR-10 Batch 3:  Loss= 0.7497, Accuracy= 0.5778
# Epoch 13, CIFAR-10 Batch 4:  Loss= 0.7121, Accuracy= 0.5994
# Epoch 13, CIFAR-10 Batch 5:  Loss= 0.7752, Accuracy= 0.6038
# Epoch 14, CIFAR-10 Batch 1:  Loss= 0.8801, Accuracy= 0.5998
# Epoch 14, CIFAR-10 Batch 2:  Loss= 0.8125, Accuracy= 0.5830
# Epoch 14, CIFAR-10 Batch 3:  Loss= 0.7360, Accuracy= 0.5818
# Epoch 14, CIFAR-10 Batch 4:  Loss= 0.6789, Accuracy= 0.6018
# Epoch 14, CIFAR-10 Batch 5:  Loss= 0.7348, Accuracy= 0.6160
# Epoch 15, CIFAR-10 Batch 1:  Loss= 0.8278, Accuracy= 0.5910
# Epoch 15, CIFAR-10 Batch 2:  Loss= 0.7596, Accuracy= 0.5900
# Epoch 15, CIFAR-10 Batch 3:  Loss= 0.6702, Accuracy= 0.5958
# Epoch 15, CIFAR-10 Batch 4:  Loss= 0.6240, Accuracy= 0.6124
# Epoch 15, CIFAR-10 Batch 5:  Loss= 0.6751, Accuracy= 0.6136
# Epoch 16, CIFAR-10 Batch 1:  Loss= 0.7634, Accuracy= 0.5972
# Epoch 16, CIFAR-10 Batch 2:  Loss= 0.7148, Accuracy= 0.5860
# Epoch 16, CIFAR-10 Batch 3:  Loss= 0.6578, Accuracy= 0.5942
# Epoch 16, CIFAR-10 Batch 4:  Loss= 0.6036, Accuracy= 0.6092
# Epoch 16, CIFAR-10 Batch 5:  Loss= 0.6506, Accuracy= 0.6174
# Epoch 17, CIFAR-10 Batch 1:  Loss= 0.7407, Accuracy= 0.6004
# Epoch 17, CIFAR-10 Batch 2:  Loss= 0.6475, Accuracy= 0.6024
# Epoch 17, CIFAR-10 Batch 3:  Loss= 0.5973, Accuracy= 0.6002
# Epoch 17, CIFAR-10 Batch 4:  Loss= 0.5712, Accuracy= 0.6124
# Epoch 17, CIFAR-10 Batch 5:  Loss= 0.6132, Accuracy= 0.6172
# Epoch 18, CIFAR-10 Batch 1:  Loss= 0.6809, Accuracy= 0.6060
# Epoch 18, CIFAR-10 Batch 2:  Loss= 0.5788, Accuracy= 0.6064
# Epoch 18, CIFAR-10 Batch 3:  Loss= 0.5692, Accuracy= 0.6002
# Epoch 18, CIFAR-10 Batch 4:  Loss= 0.5471, Accuracy= 0.6128
# Epoch 18, CIFAR-10 Batch 5:  Loss= 0.6090, Accuracy= 0.6148
# Epoch 19, CIFAR-10 Batch 1:  Loss= 0.6457, Accuracy= 0.6168
# Epoch 19, CIFAR-10 Batch 2:  Loss= 0.5907, Accuracy= 0.5918
# Epoch 19, CIFAR-10 Batch 3:  Loss= 0.5453, Accuracy= 0.6128
# Epoch 19, CIFAR-10 Batch 4:  Loss= 0.5084, Accuracy= 0.6120
# Epoch 19, CIFAR-10 Batch 5:  Loss= 0.5705, Accuracy= 0.6180
# Epoch 20, CIFAR-10 Batch 1:  Loss= 0.6014, Accuracy= 0.6160
# Epoch 20, CIFAR-10 Batch 2:  Loss= 0.5698, Accuracy= 0.5912
# Epoch 20, CIFAR-10 Batch 3:  Loss= 0.5202, Accuracy= 0.6014
# Epoch 20, CIFAR-10 Batch 4:  Loss= 0.5142, Accuracy= 0.6108
# Epoch 20, CIFAR-10 Batch 5:  Loss= 0.5243, Accuracy= 0.6146
# Epoch 21, CIFAR-10 Batch 1:  Loss= 0.5484, Accuracy= 0.6298
# Epoch 21, CIFAR-10 Batch 2:  Loss= 0.5312, Accuracy= 0.5968
# Epoch 21, CIFAR-10 Batch 3:  Loss= 0.4758, Accuracy= 0.6100
# Epoch 21, CIFAR-10 Batch 4:  Loss= 0.4312, Accuracy= 0.6216
# Epoch 21, CIFAR-10 Batch 5:  Loss= 0.4917, Accuracy= 0.6204
# Epoch 22, CIFAR-10 Batch 1:  Loss= 0.5165, Accuracy= 0.6256
# Epoch 22, CIFAR-10 Batch 2:  Loss= 0.4949, Accuracy= 0.6000
# Epoch 22, CIFAR-10 Batch 3:  Loss= 0.4744, Accuracy= 0.6014
# Epoch 22, CIFAR-10 Batch 4:  Loss= 0.4185, Accuracy= 0.6108
# Epoch 22, CIFAR-10 Batch 5:  Loss= 0.4609, Accuracy= 0.6210
# Epoch 23, CIFAR-10 Batch 1:  Loss= 0.4923, Accuracy= 0.6236
# Epoch 23, CIFAR-10 Batch 2:  Loss= 0.4819, Accuracy= 0.6038
# Epoch 23, CIFAR-10 Batch 3:  Loss= 0.3983, Accuracy= 0.6098
# Epoch 23, CIFAR-10 Batch 4:  Loss= 0.3755, Accuracy= 0.6150
# Epoch 23, CIFAR-10 Batch 5:  Loss= 0.4042, Accuracy= 0.6174
# Epoch 24, CIFAR-10 Batch 1:  Loss= 0.4269, Accuracy= 0.6214
# Epoch 24, CIFAR-10 Batch 2:  Loss= 0.4139, Accuracy= 0.6102
# Epoch 24, CIFAR-10 Batch 3:  Loss= 0.3721, Accuracy= 0.6212
# Epoch 24, CIFAR-10 Batch 4:  Loss= 0.3468, Accuracy= 0.6184
# Epoch 24, CIFAR-10 Batch 5:  Loss= 0.3870, Accuracy= 0.6192
# Epoch 25, CIFAR-10 Batch 1:  Loss= 0.3927, Accuracy= 0.6258
# Epoch 25, CIFAR-10 Batch 2:  Loss= 0.3893, Accuracy= 0.6066
# Epoch 25, CIFAR-10 Batch 3:  Loss= 0.3529, Accuracy= 0.6118
# Epoch 25, CIFAR-10 Batch 4:  Loss= 0.3383, Accuracy= 0.6100
# Epoch 25, CIFAR-10 Batch 5:  Loss= 0.3468, Accuracy= 0.6218
# Epoch 26, CIFAR-10 Batch 1:  Loss= 0.3545, Accuracy= 0.6202
# Epoch 26, CIFAR-10 Batch 2:  Loss= 0.3419, Accuracy= 0.6142
# Epoch 26, CIFAR-10 Batch 3:  Loss= 0.3404, Accuracy= 0.6064
# Epoch 26, CIFAR-10 Batch 4:  Loss= 0.3283, Accuracy= 0.6112
# Epoch 26, CIFAR-10 Batch 5:  Loss= 0.3290, Accuracy= 0.6206
# Epoch 27, CIFAR-10 Batch 1:  Loss= 0.3363, Accuracy= 0.6158
# Epoch 27, CIFAR-10 Batch 2:  Loss= 0.3333, Accuracy= 0.6100
# Epoch 27, CIFAR-10 Batch 3:  Loss= 0.3332, Accuracy= 0.6120
# Epoch 27, CIFAR-10 Batch 4:  Loss= 0.2924, Accuracy= 0.6142
# Epoch 27, CIFAR-10 Batch 5:  Loss= 0.3102, Accuracy= 0.6148
# Epoch 28, CIFAR-10 Batch 1:  Loss= 0.3663, Accuracy= 0.6146
# Epoch 28, CIFAR-10 Batch 2:  Loss= 0.3094, Accuracy= 0.6186
# Epoch 28, CIFAR-10 Batch 3:  Loss= 0.3290, Accuracy= 0.6128
# Epoch 28, CIFAR-10 Batch 4:  Loss= 0.2869, Accuracy= 0.6146
# Epoch 28, CIFAR-10 Batch 5:  Loss= 0.2950, Accuracy= 0.6116
# Epoch 29, CIFAR-10 Batch 1:  Loss= 0.3200, Accuracy= 0.6220
# Epoch 29, CIFAR-10 Batch 2:  Loss= 0.2925, Accuracy= 0.6184
# Epoch 29, CIFAR-10 Batch 3:  Loss= 0.3001, Accuracy= 0.6124
# Epoch 29, CIFAR-10 Batch 4:  Loss= 0.2392, Accuracy= 0.6166
# Epoch 29, CIFAR-10 Batch 5:  Loss= 0.2459, Accuracy= 0.6118
# Epoch 30, CIFAR-10 Batch 1:  Loss= 0.2717, Accuracy= 0.6234
# Epoch 30, CIFAR-10 Batch 2:  Loss= 0.2905, Accuracy= 0.6100
# Epoch 30, CIFAR-10 Batch 3:  Loss= 0.3188, Accuracy= 0.6058
# Epoch 30, CIFAR-10 Batch 4:  Loss= 0.2444, Accuracy= 0.6158
# Epoch 30, CIFAR-10 Batch 5:  Loss= 0.2643, Accuracy= 0.6144
# Epoch 31, CIFAR-10 Batch 1:  Loss= 0.2719, Accuracy= 0.6172
# Epoch 31, CIFAR-10 Batch 2:  Loss= 0.2457, Accuracy= 0.6164
# Epoch 31, CIFAR-10 Batch 3:  Loss= 0.2621, Accuracy= 0.6088
# Epoch 31, CIFAR-10 Batch 4:  Loss= 0.2039, Accuracy= 0.6176
# Epoch 31, CIFAR-10 Batch 5:  Loss= 0.2173, Accuracy= 0.6192
# Epoch 32, CIFAR-10 Batch 1:  Loss= 0.2435, Accuracy= 0.6238
# Epoch 32, CIFAR-10 Batch 2:  Loss= 0.2286, Accuracy= 0.6088
# Epoch 32, CIFAR-10 Batch 3:  Loss= 0.2388, Accuracy= 0.6154
# Epoch 32, CIFAR-10 Batch 4:  Loss= 0.2227, Accuracy= 0.6024
# Epoch 32, CIFAR-10 Batch 5:  Loss= 0.2239, Accuracy= 0.6230
# Epoch 33, CIFAR-10 Batch 1:  Loss= 0.2117, Accuracy= 0.6306
# Epoch 33, CIFAR-10 Batch 2:  Loss= 0.2175, Accuracy= 0.6168
# Epoch 33, CIFAR-10 Batch 3:  Loss= 0.2323, Accuracy= 0.6050
# Epoch 33, CIFAR-10 Batch 4:  Loss= 0.1818, Accuracy= 0.6072
# Epoch 33, CIFAR-10 Batch 5:  Loss= 0.1971, Accuracy= 0.6238
# Epoch 34, CIFAR-10 Batch 1:  Loss= 0.2072, Accuracy= 0.6278
# Epoch 34, CIFAR-10 Batch 2:  Loss= 0.1926, Accuracy= 0.6162
# Epoch 34, CIFAR-10 Batch 3:  Loss= 0.1990, Accuracy= 0.6062
# Epoch 34, CIFAR-10 Batch 4:  Loss= 0.1767, Accuracy= 0.6082
# Epoch 34, CIFAR-10 Batch 5:  Loss= 0.1913, Accuracy= 0.6208
# Epoch 35, CIFAR-10 Batch 1:  Loss= 0.2134, Accuracy= 0.6120
# Epoch 35, CIFAR-10 Batch 2:  Loss= 0.1993, Accuracy= 0.6116
# Epoch 35, CIFAR-10 Batch 3:  Loss= 0.1832, Accuracy= 0.6126
# Epoch 35, CIFAR-10 Batch 4:  Loss= 0.1590, Accuracy= 0.6138
# Epoch 35, CIFAR-10 Batch 5:  Loss= 0.1977, Accuracy= 0.6082
# Epoch 36, CIFAR-10 Batch 1:  Loss= 0.1837, Accuracy= 0.6066
# Epoch 36, CIFAR-10 Batch 2:  Loss= 0.1609, Accuracy= 0.6096
# Epoch 36, CIFAR-10 Batch 3:  Loss= 0.1545, Accuracy= 0.6138
# Epoch 36, CIFAR-10 Batch 4:  Loss= 0.1617, Accuracy= 0.6096
# Epoch 36, CIFAR-10 Batch 5:  Loss= 0.1663, Accuracy= 0.6138
# Epoch 37, CIFAR-10 Batch 1:  Loss= 0.1625, Accuracy= 0.6154
# Epoch 37, CIFAR-10 Batch 2:  Loss= 0.1449, Accuracy= 0.6106
# Epoch 37, CIFAR-10 Batch 3:  Loss= 0.1399, Accuracy= 0.6170
# Epoch 37, CIFAR-10 Batch 4:  Loss= 0.1533, Accuracy= 0.6076
# Epoch 37, CIFAR-10 Batch 5:  Loss= 0.1512, Accuracy= 0.6164
# Epoch 38, CIFAR-10 Batch 1:  Loss= 0.1686, Accuracy= 0.6192
# Epoch 38, CIFAR-10 Batch 2:  Loss= 0.1547, Accuracy= 0.6064
# Epoch 38, CIFAR-10 Batch 3:  Loss= 0.1521, Accuracy= 0.6120
# Epoch 38, CIFAR-10 Batch 4:  Loss= 0.1375, Accuracy= 0.6202
# Epoch 38, CIFAR-10 Batch 5:  Loss= 0.1303, Accuracy= 0.6198
# Epoch 39, CIFAR-10 Batch 1:  Loss= 0.1688, Accuracy= 0.6038
# Epoch 39, CIFAR-10 Batch 2:  Loss= 0.1496, Accuracy= 0.6060
# Epoch 39, CIFAR-10 Batch 3:  Loss= 0.1625, Accuracy= 0.6060
# Epoch 39, CIFAR-10 Batch 4:  Loss= 0.1370, Accuracy= 0.6188
# Epoch 39, CIFAR-10 Batch 5:  Loss= 0.1582, Accuracy= 0.6118
# Epoch 40, CIFAR-10 Batch 1:  Loss= 0.1740, Accuracy= 0.6078
# Epoch 40, CIFAR-10 Batch 2:  Loss= 0.1136, Accuracy= 0.6164
# Epoch 40, CIFAR-10 Batch 3:  Loss= 0.1242, Accuracy= 0.5986
# Epoch 40, CIFAR-10 Batch 4:  Loss= 0.1100, Accuracy= 0.6170
# Epoch 40, CIFAR-10 Batch 5:  Loss= 0.1446, Accuracy= 0.6032
# Epoch 41, CIFAR-10 Batch 1:  Loss= 0.1227, Accuracy= 0.6224
# Epoch 41, CIFAR-10 Batch 2:  Loss= 0.0977, Accuracy= 0.6172
# Epoch 41, CIFAR-10 Batch 3:  Loss= 0.1006, Accuracy= 0.6234
# Epoch 41, CIFAR-10 Batch 4:  Loss= 0.1108, Accuracy= 0.6110
# Epoch 41, CIFAR-10 Batch 5:  Loss= 0.1036, Accuracy= 0.6106
# Epoch 42, CIFAR-10 Batch 1:  Loss= 0.1402, Accuracy= 0.6242
# Epoch 42, CIFAR-10 Batch 2:  Loss= 0.0925, Accuracy= 0.6142
# Epoch 42, CIFAR-10 Batch 3:  Loss= 0.0890, Accuracy= 0.6218
# Epoch 42, CIFAR-10 Batch 4:  Loss= 0.1240, Accuracy= 0.6080
# Epoch 42, CIFAR-10 Batch 5:  Loss= 0.1230, Accuracy= 0.6160
# Epoch 43, CIFAR-10 Batch 1:  Loss= 0.0984, Accuracy= 0.6218
# Epoch 43, CIFAR-10 Batch 2:  Loss= 0.0799, Accuracy= 0.6214
# Epoch 43, CIFAR-10 Batch 3:  Loss= 0.0671, Accuracy= 0.6270
# Epoch 43, CIFAR-10 Batch 4:  Loss= 0.0910, Accuracy= 0.6106
# Epoch 43, CIFAR-10 Batch 5:  Loss= 0.0981, Accuracy= 0.6224
# Epoch 44, CIFAR-10 Batch 1:  Loss= 0.1041, Accuracy= 0.6168
# Epoch 44, CIFAR-10 Batch 2:  Loss= 0.0737, Accuracy= 0.6200
# Epoch 44, CIFAR-10 Batch 3:  Loss= 0.0737, Accuracy= 0.6256
# Epoch 44, CIFAR-10 Batch 4:  Loss= 0.0835, Accuracy= 0.6060
# Epoch 44, CIFAR-10 Batch 5:  Loss= 0.0798, Accuracy= 0.6188
# Epoch 45, CIFAR-10 Batch 1:  Loss= 0.0821, Accuracy= 0.6156
# Epoch 45, CIFAR-10 Batch 2:  Loss= 0.0590, Accuracy= 0.6226
# Epoch 45, CIFAR-10 Batch 3:  Loss= 0.0616, Accuracy= 0.6194
# Epoch 45, CIFAR-10 Batch 4:  Loss= 0.0786, Accuracy= 0.6074
# Epoch 45, CIFAR-10 Batch 5:  Loss= 0.0738, Accuracy= 0.6148
# Epoch 46, CIFAR-10 Batch 1:  Loss= 0.0772, Accuracy= 0.6132
# Epoch 46, CIFAR-10 Batch 2:  Loss= 0.0519, Accuracy= 0.6218
# Epoch 46, CIFAR-10 Batch 3:  Loss= 0.0519, Accuracy= 0.6188
# Epoch 46, CIFAR-10 Batch 4:  Loss= 0.0882, Accuracy= 0.6148
# Epoch 46, CIFAR-10 Batch 5:  Loss= 0.0722, Accuracy= 0.6084
# Epoch 47, CIFAR-10 Batch 1:  Loss= 0.0694, Accuracy= 0.6180
# Epoch 47, CIFAR-10 Batch 2:  Loss= 0.0521, Accuracy= 0.6142
# Epoch 47, CIFAR-10 Batch 3:  Loss= 0.0520, Accuracy= 0.6236
# Epoch 47, CIFAR-10 Batch 4:  Loss= 0.0773, Accuracy= 0.6080
# Epoch 47, CIFAR-10 Batch 5:  Loss= 0.0752, Accuracy= 0.6096
# Epoch 48, CIFAR-10 Batch 1:  Loss= 0.0775, Accuracy= 0.6142
# Epoch 48, CIFAR-10 Batch 2:  Loss= 0.0520, Accuracy= 0.6188
# Epoch 48, CIFAR-10 Batch 3:  Loss= 0.0449, Accuracy= 0.6196
# Epoch 48, CIFAR-10 Batch 4:  Loss= 0.0719, Accuracy= 0.6132
# Epoch 48, CIFAR-10 Batch 5:  Loss= 0.0461, Accuracy= 0.6206
# Epoch 49, CIFAR-10 Batch 1:  Loss= 0.0598, Accuracy= 0.6154
# Epoch 49, CIFAR-10 Batch 2:  Loss= 0.0539, Accuracy= 0.6210
# Epoch 49, CIFAR-10 Batch 3:  Loss= 0.0437, Accuracy= 0.6244
# Epoch 49, CIFAR-10 Batch 4:  Loss= 0.0762, Accuracy= 0.6052
# Epoch 49, CIFAR-10 Batch 5:  Loss= 0.0561, Accuracy= 0.6164
# Epoch 50, CIFAR-10 Batch 1:  Loss= 0.0613, Accuracy= 0.6196
# Epoch 50, CIFAR-10 Batch 2:  Loss= 0.0588, Accuracy= 0.6160
# Epoch 50, CIFAR-10 Batch 3:  Loss= 0.0419, Accuracy= 0.6254
# Epoch 50, CIFAR-10 Batch 4:  Loss= 0.0661, Accuracy= 0.6126
# Epoch 50, CIFAR-10 Batch 5:  Loss= 0.0436, Accuracy= 0.6258
# Epoch 51, CIFAR-10 Batch 1:  Loss= 0.0521, Accuracy= 0.6232
# Epoch 51, CIFAR-10 Batch 2:  Loss= 0.0468, Accuracy= 0.6142
# Epoch 51, CIFAR-10 Batch 3:  Loss= 0.0471, Accuracy= 0.6194
# Epoch 51, CIFAR-10 Batch 4:  Loss= 0.0550, Accuracy= 0.6128
# Epoch 51, CIFAR-10 Batch 5:  Loss= 0.0478, Accuracy= 0.6214
# Epoch 52, CIFAR-10 Batch 1:  Loss= 0.0606, Accuracy= 0.6242
# Epoch 52, CIFAR-10 Batch 2:  Loss= 0.0460, Accuracy= 0.6166
# Epoch 52, CIFAR-10 Batch 3:  Loss= 0.0418, Accuracy= 0.6182
# Epoch 52, CIFAR-10 Batch 4:  Loss= 0.0459, Accuracy= 0.6178
# Epoch 52, CIFAR-10 Batch 5:  Loss= 0.0426, Accuracy= 0.6216
# Epoch 53, CIFAR-10 Batch 1:  Loss= 0.0492, Accuracy= 0.6198
# Epoch 53, CIFAR-10 Batch 2:  Loss= 0.0382, Accuracy= 0.6174
# Epoch 53, CIFAR-10 Batch 3:  Loss= 0.0397, Accuracy= 0.6098
# Epoch 53, CIFAR-10 Batch 4:  Loss= 0.0530, Accuracy= 0.6138
# Epoch 53, CIFAR-10 Batch 5:  Loss= 0.0575, Accuracy= 0.6056
# Epoch 54, CIFAR-10 Batch 1:  Loss= 0.0545, Accuracy= 0.6118
# Epoch 54, CIFAR-10 Batch 2:  Loss= 0.0466, Accuracy= 0.6100
# Epoch 54, CIFAR-10 Batch 3:  Loss= 0.0350, Accuracy= 0.6238
# Epoch 54, CIFAR-10 Batch 4:  Loss= 0.0498, Accuracy= 0.6160
# Epoch 54, CIFAR-10 Batch 5:  Loss= 0.0475, Accuracy= 0.6070
# Epoch 55, CIFAR-10 Batch 1:  Loss= 0.0672, Accuracy= 0.5922
# Epoch 55, CIFAR-10 Batch 2:  Loss= 0.0422, Accuracy= 0.6054
# Epoch 55, CIFAR-10 Batch 3:  Loss= 0.0359, Accuracy= 0.6214
# Epoch 55, CIFAR-10 Batch 4:  Loss= 0.0564, Accuracy= 0.6146
# Epoch 55, CIFAR-10 Batch 5:  Loss= 0.0498, Accuracy= 0.5982
# Epoch 56, CIFAR-10 Batch 1:  Loss= 0.0680, Accuracy= 0.5902
# Epoch 56, CIFAR-10 Batch 2:  Loss= 0.0283, Accuracy= 0.6134
# Epoch 56, CIFAR-10 Batch 3:  Loss= 0.0348, Accuracy= 0.6238
# Epoch 56, CIFAR-10 Batch 4:  Loss= 0.0661, Accuracy= 0.6076
# Epoch 56, CIFAR-10 Batch 5:  Loss= 0.0401, Accuracy= 0.6038
# Epoch 57, CIFAR-10 Batch 1:  Loss= 0.0378, Accuracy= 0.6094
# Epoch 57, CIFAR-10 Batch 2:  Loss= 0.0456, Accuracy= 0.6100
# Epoch 57, CIFAR-10 Batch 3:  Loss= 0.0612, Accuracy= 0.6040
# Epoch 57, CIFAR-10 Batch 4:  Loss= 0.0454, Accuracy= 0.6142
# Epoch 57, CIFAR-10 Batch 5:  Loss= 0.0412, Accuracy= 0.6108
# Epoch 58, CIFAR-10 Batch 1:  Loss= 0.0694, Accuracy= 0.6166
# Epoch 58, CIFAR-10 Batch 2:  Loss= 0.0451, Accuracy= 0.6184
# Epoch 58, CIFAR-10 Batch 3:  Loss= 0.0362, Accuracy= 0.6126
# Epoch 58, CIFAR-10 Batch 4:  Loss= 0.0355, Accuracy= 0.6104
# Epoch 58, CIFAR-10 Batch 5:  Loss= 0.0715, Accuracy= 0.5910
# Epoch 59, CIFAR-10 Batch 1:  Loss= 0.0580, Accuracy= 0.6002
# Epoch 59, CIFAR-10 Batch 2:  Loss= 0.0343, Accuracy= 0.6160
# Epoch 59, CIFAR-10 Batch 3:  Loss= 0.0235, Accuracy= 0.6284
# Epoch 59, CIFAR-10 Batch 4:  Loss= 0.0422, Accuracy= 0.6090
# Epoch 59, CIFAR-10 Batch 5:  Loss= 0.0349, Accuracy= 0.6116
# Epoch 60, CIFAR-10 Batch 1:  Loss= 0.0450, Accuracy= 0.6194
# Epoch 60, CIFAR-10 Batch 2:  Loss= 0.0260, Accuracy= 0.6204
# Epoch 60, CIFAR-10 Batch 3:  Loss= 0.0237, Accuracy= 0.6234
# Epoch 60, CIFAR-10 Batch 4:  Loss= 0.0337, Accuracy= 0.6204
# Epoch 60, CIFAR-10 Batch 5:  Loss= 0.0407, Accuracy= 0.6190
# Epoch 61, CIFAR-10 Batch 1:  Loss= 0.0333, Accuracy= 0.6242
# Epoch 61, CIFAR-10 Batch 2:  Loss= 0.0299, Accuracy= 0.6140
# Epoch 61, CIFAR-10 Batch 3:  Loss= 0.0254, Accuracy= 0.6182
# Epoch 61, CIFAR-10 Batch 4:  Loss= 0.0304, Accuracy= 0.6172
# Epoch 61, CIFAR-10 Batch 5:  Loss= 0.0276, Accuracy= 0.6108
# Epoch 62, CIFAR-10 Batch 1:  Loss= 0.0326, Accuracy= 0.6260
# Epoch 62, CIFAR-10 Batch 2:  Loss= 0.0304, Accuracy= 0.6064
# Epoch 62, CIFAR-10 Batch 3:  Loss= 0.0234, Accuracy= 0.6172
# Epoch 62, CIFAR-10 Batch 4:  Loss= 0.0300, Accuracy= 0.6132
# Epoch 62, CIFAR-10 Batch 5:  Loss= 0.0256, Accuracy= 0.6224
# Epoch 63, CIFAR-10 Batch 1:  Loss= 0.0240, Accuracy= 0.6188
# Epoch 63, CIFAR-10 Batch 2:  Loss= 0.0241, Accuracy= 0.6188
# Epoch 63, CIFAR-10 Batch 3:  Loss= 0.0155, Accuracy= 0.6210
# Epoch 63, CIFAR-10 Batch 4:  Loss= 0.0213, Accuracy= 0.6128
# Epoch 63, CIFAR-10 Batch 5:  Loss= 0.0280, Accuracy= 0.6238
# Epoch 64, CIFAR-10 Batch 1:  Loss= 0.0211, Accuracy= 0.6222
# Epoch 64, CIFAR-10 Batch 2:  Loss= 0.0240, Accuracy= 0.6208
# Epoch 64, CIFAR-10 Batch 3:  Loss= 0.0116, Accuracy= 0.6244
# Epoch 64, CIFAR-10 Batch 4:  Loss= 0.0193, Accuracy= 0.6128
# Epoch 64, CIFAR-10 Batch 5:  Loss= 0.0209, Accuracy= 0.6246
# Epoch 65, CIFAR-10 Batch 1:  Loss= 0.0209, Accuracy= 0.6254
# Epoch 65, CIFAR-10 Batch 2:  Loss= 0.0126, Accuracy= 0.6238
# Epoch 65, CIFAR-10 Batch 3:  Loss= 0.0103, Accuracy= 0.6236
# Epoch 65, CIFAR-10 Batch 4:  Loss= 0.0158, Accuracy= 0.6120
# Epoch 65, CIFAR-10 Batch 5:  Loss= 0.0181, Accuracy= 0.6290
# Epoch 66, CIFAR-10 Batch 1:  Loss= 0.0133, Accuracy= 0.6222
# Epoch 66, CIFAR-10 Batch 2:  Loss= 0.0161, Accuracy= 0.6266
# Epoch 66, CIFAR-10 Batch 3:  Loss= 0.0111, Accuracy= 0.6226
# Epoch 66, CIFAR-10 Batch 4:  Loss= 0.0189, Accuracy= 0.6074
# Epoch 66, CIFAR-10 Batch 5:  Loss= 0.0152, Accuracy= 0.6156
# Epoch 67, CIFAR-10 Batch 1:  Loss= 0.0140, Accuracy= 0.6182
# Epoch 67, CIFAR-10 Batch 2:  Loss= 0.0107, Accuracy= 0.6212
# Epoch 67, CIFAR-10 Batch 3:  Loss= 0.0099, Accuracy= 0.6198
# Epoch 67, CIFAR-10 Batch 4:  Loss= 0.0141, Accuracy= 0.6182
# Epoch 67, CIFAR-10 Batch 5:  Loss= 0.0146, Accuracy= 0.6206
# Epoch 68, CIFAR-10 Batch 1:  Loss= 0.0097, Accuracy= 0.6268
# Epoch 68, CIFAR-10 Batch 2:  Loss= 0.0122, Accuracy= 0.6260
# Epoch 68, CIFAR-10 Batch 3:  Loss= 0.0113, Accuracy= 0.6252
# Epoch 68, CIFAR-10 Batch 4:  Loss= 0.0154, Accuracy= 0.6176
# Epoch 68, CIFAR-10 Batch 5:  Loss= 0.0128, Accuracy= 0.6166
# Epoch 69, CIFAR-10 Batch 1:  Loss= 0.0182, Accuracy= 0.6204
# Epoch 69, CIFAR-10 Batch 2:  Loss= 0.0106, Accuracy= 0.6182
# Epoch 69, CIFAR-10 Batch 3:  Loss= 0.0089, Accuracy= 0.6316
# Epoch 69, CIFAR-10 Batch 4:  Loss= 0.0195, Accuracy= 0.6156
# Epoch 69, CIFAR-10 Batch 5:  Loss= 0.0123, Accuracy= 0.6188
# Epoch 70, CIFAR-10 Batch 1:  Loss= 0.0090, Accuracy= 0.6230
# Epoch 70, CIFAR-10 Batch 2:  Loss= 0.0087, Accuracy= 0.6258
# Epoch 70, CIFAR-10 Batch 3:  Loss= 0.0105, Accuracy= 0.6210
# Epoch 70, CIFAR-10 Batch 4:  Loss= 0.0122, Accuracy= 0.6234
# Epoch 70, CIFAR-10 Batch 5:  Loss= 0.0118, Accuracy= 0.6160
# Epoch 71, CIFAR-10 Batch 1:  Loss= 0.0130, Accuracy= 0.6204
# Epoch 71, CIFAR-10 Batch 2:  Loss= 0.0079, Accuracy= 0.6198
# Epoch 71, CIFAR-10 Batch 3:  Loss= 0.0138, Accuracy= 0.6226
# Epoch 71, CIFAR-10 Batch 4:  Loss= 0.0119, Accuracy= 0.6252
# Epoch 71, CIFAR-10 Batch 5:  Loss= 0.0121, Accuracy= 0.6172
# Epoch 72, CIFAR-10 Batch 1:  Loss= 0.0124, Accuracy= 0.6212
# Epoch 72, CIFAR-10 Batch 2:  Loss= 0.0121, Accuracy= 0.6180
# Epoch 72, CIFAR-10 Batch 3:  Loss= 0.0093, Accuracy= 0.6232
# Epoch 72, CIFAR-10 Batch 4:  Loss= 0.0099, Accuracy= 0.6208
# Epoch 72, CIFAR-10 Batch 5:  Loss= 0.0116, Accuracy= 0.6108
# Epoch 73, CIFAR-10 Batch 1:  Loss= 0.0097, Accuracy= 0.6204
# Epoch 73, CIFAR-10 Batch 2:  Loss= 0.0085, Accuracy= 0.6204
# Epoch 73, CIFAR-10 Batch 3:  Loss= 0.0082, Accuracy= 0.6224
# Epoch 73, CIFAR-10 Batch 4:  Loss= 0.0099, Accuracy= 0.6222
# Epoch 73, CIFAR-10 Batch 5:  Loss= 0.0206, Accuracy= 0.6058
# Epoch 74, CIFAR-10 Batch 1:  Loss= 0.0111, Accuracy= 0.6204
# Epoch 74, CIFAR-10 Batch 2:  Loss= 0.0100, Accuracy= 0.6198
# Epoch 74, CIFAR-10 Batch 3:  Loss= 0.0062, Accuracy= 0.6272
# Epoch 74, CIFAR-10 Batch 4:  Loss= 0.0111, Accuracy= 0.6170
# Epoch 74, CIFAR-10 Batch 5:  Loss= 0.0154, Accuracy= 0.6066
# Epoch 75, CIFAR-10 Batch 1:  Loss= 0.0135, Accuracy= 0.6102
# Epoch 75, CIFAR-10 Batch 2:  Loss= 0.0138, Accuracy= 0.6174
# Epoch 75, CIFAR-10 Batch 3:  Loss= 0.0097, Accuracy= 0.6184
# Epoch 75, CIFAR-10 Batch 4:  Loss= 0.0078, Accuracy= 0.6214
# Epoch 75, CIFAR-10 Batch 5:  Loss= 0.0128, Accuracy= 0.6140
# Epoch 76, CIFAR-10 Batch 1:  Loss= 0.0150, Accuracy= 0.6124
# Epoch 76, CIFAR-10 Batch 2:  Loss= 0.0080, Accuracy= 0.6158
# Epoch 76, CIFAR-10 Batch 3:  Loss= 0.0079, Accuracy= 0.6222
# Epoch 76, CIFAR-10 Batch 4:  Loss= 0.0102, Accuracy= 0.6202
# Epoch 76, CIFAR-10 Batch 5:  Loss= 0.0138, Accuracy= 0.6110
# Epoch 77, CIFAR-10 Batch 1:  Loss= 0.0130, Accuracy= 0.6138
# Epoch 77, CIFAR-10 Batch 2:  Loss= 0.0090, Accuracy= 0.6094
# Epoch 77, CIFAR-10 Batch 3:  Loss= 0.0163, Accuracy= 0.6154
# Epoch 77, CIFAR-10 Batch 4:  Loss= 0.0142, Accuracy= 0.6192
# Epoch 77, CIFAR-10 Batch 5:  Loss= 0.0100, Accuracy= 0.6126
# Epoch 78, CIFAR-10 Batch 1:  Loss= 0.0146, Accuracy= 0.6194
# Epoch 78, CIFAR-10 Batch 2:  Loss= 0.0075, Accuracy= 0.6176
# Epoch 78, CIFAR-10 Batch 3:  Loss= 0.0101, Accuracy= 0.6218
# Epoch 78, CIFAR-10 Batch 4:  Loss= 0.0132, Accuracy= 0.6250
# Epoch 78, CIFAR-10 Batch 5:  Loss= 0.0106, Accuracy= 0.6122
# Epoch 79, CIFAR-10 Batch 1:  Loss= 0.0085, Accuracy= 0.6176
# Epoch 79, CIFAR-10 Batch 2:  Loss= 0.0078, Accuracy= 0.6240
# Epoch 79, CIFAR-10 Batch 3:  Loss= 0.0120, Accuracy= 0.6136
# Epoch 79, CIFAR-10 Batch 4:  Loss= 0.0150, Accuracy= 0.6164
# Epoch 79, CIFAR-10 Batch 5:  Loss= 0.0138, Accuracy= 0.6098
# Epoch 80, CIFAR-10 Batch 1:  Loss= 0.0079, Accuracy= 0.6206
# Epoch 80, CIFAR-10 Batch 2:  Loss= 0.0084, Accuracy= 0.6114
# Epoch 80, CIFAR-10 Batch 3:  Loss= 0.0100, Accuracy= 0.6176
# Epoch 80, CIFAR-10 Batch 4:  Loss= 0.0098, Accuracy= 0.6208
# Epoch 80, CIFAR-10 Batch 5:  Loss= 0.0074, Accuracy= 0.6204
# Epoch 81, CIFAR-10 Batch 1:  Loss= 0.0117, Accuracy= 0.6236
# Epoch 81, CIFAR-10 Batch 2:  Loss= 0.0158, Accuracy= 0.6118
# Epoch 81, CIFAR-10 Batch 3:  Loss= 0.0067, Accuracy= 0.6214
# Epoch 81, CIFAR-10 Batch 4:  Loss= 0.0140, Accuracy= 0.6270
# Epoch 81, CIFAR-10 Batch 5:  Loss= 0.0099, Accuracy= 0.6276
# Epoch 82, CIFAR-10 Batch 1:  Loss= 0.0113, Accuracy= 0.6178
# Epoch 82, CIFAR-10 Batch 2:  Loss= 0.0106, Accuracy= 0.6202
# Epoch 82, CIFAR-10 Batch 3:  Loss= 0.0098, Accuracy= 0.6210
# Epoch 82, CIFAR-10 Batch 4:  Loss= 0.0107, Accuracy= 0.6212
# Epoch 82, CIFAR-10 Batch 5:  Loss= 0.0142, Accuracy= 0.6258
# Epoch 83, CIFAR-10 Batch 1:  Loss= 0.0089, Accuracy= 0.6258
# Epoch 83, CIFAR-10 Batch 2:  Loss= 0.0083, Accuracy= 0.6172
# Epoch 83, CIFAR-10 Batch 3:  Loss= 0.0097, Accuracy= 0.6262
# Epoch 83, CIFAR-10 Batch 4:  Loss= 0.0086, Accuracy= 0.6188
# Epoch 83, CIFAR-10 Batch 5:  Loss= 0.0109, Accuracy= 0.6354
# Epoch 84, CIFAR-10 Batch 1:  Loss= 0.0081, Accuracy= 0.6230
# Epoch 84, CIFAR-10 Batch 2:  Loss= 0.0059, Accuracy= 0.6178
# Epoch 84, CIFAR-10 Batch 3:  Loss= 0.0110, Accuracy= 0.6208
# Epoch 84, CIFAR-10 Batch 4:  Loss= 0.0121, Accuracy= 0.6234
# Epoch 84, CIFAR-10 Batch 5:  Loss= 0.0084, Accuracy= 0.6270
# Epoch 85, CIFAR-10 Batch 1:  Loss= 0.0059, Accuracy= 0.6326
# Epoch 85, CIFAR-10 Batch 2:  Loss= 0.0098, Accuracy= 0.6166
# Epoch 85, CIFAR-10 Batch 3:  Loss= 0.0091, Accuracy= 0.6230
# Epoch 85, CIFAR-10 Batch 4:  Loss= 0.0181, Accuracy= 0.6252
# Epoch 85, CIFAR-10 Batch 5:  Loss= 0.0082, Accuracy= 0.6226
# Epoch 86, CIFAR-10 Batch 1:  Loss= 0.0108, Accuracy= 0.6274
# Epoch 86, CIFAR-10 Batch 2:  Loss= 0.0050, Accuracy= 0.6166
# Epoch 86, CIFAR-10 Batch 3:  Loss= 0.0046, Accuracy= 0.6156
# Epoch 86, CIFAR-10 Batch 4:  Loss= 0.0088, Accuracy= 0.6256
# Epoch 86, CIFAR-10 Batch 5:  Loss= 0.0078, Accuracy= 0.6238
# Epoch 87, CIFAR-10 Batch 1:  Loss= 0.0088, Accuracy= 0.6298
# Epoch 87, CIFAR-10 Batch 2:  Loss= 0.0067, Accuracy= 0.6228
# Epoch 87, CIFAR-10 Batch 3:  Loss= 0.0076, Accuracy= 0.6174
# Epoch 87, CIFAR-10 Batch 4:  Loss= 0.0046, Accuracy= 0.6258
# Epoch 87, CIFAR-10 Batch 5:  Loss= 0.0053, Accuracy= 0.6136
# Epoch 88, CIFAR-10 Batch 1:  Loss= 0.0060, Accuracy= 0.6280
# Epoch 88, CIFAR-10 Batch 2:  Loss= 0.0035, Accuracy= 0.6220
# Epoch 88, CIFAR-10 Batch 3:  Loss= 0.0073, Accuracy= 0.6254
# Epoch 88, CIFAR-10 Batch 4:  Loss= 0.0106, Accuracy= 0.6306
# Epoch 88, CIFAR-10 Batch 5:  Loss= 0.0044, Accuracy= 0.6264
# Epoch 89, CIFAR-10 Batch 1:  Loss= 0.0080, Accuracy= 0.6298
# Epoch 89, CIFAR-10 Batch 2:  Loss= 0.0058, Accuracy= 0.6310
# Epoch 89, CIFAR-10 Batch 3:  Loss= 0.0056, Accuracy= 0.6232
# Epoch 89, CIFAR-10 Batch 4:  Loss= 0.0060, Accuracy= 0.6210
# Epoch 89, CIFAR-10 Batch 5:  Loss= 0.0072, Accuracy= 0.6166
# Epoch 90, CIFAR-10 Batch 1:  Loss= 0.0064, Accuracy= 0.6244
# Epoch 90, CIFAR-10 Batch 2:  Loss= 0.0027, Accuracy= 0.6238
# Epoch 90, CIFAR-10 Batch 3:  Loss= 0.0035, Accuracy= 0.6300
# Epoch 90, CIFAR-10 Batch 4:  Loss= 0.0071, Accuracy= 0.6268
# Epoch 90, CIFAR-10 Batch 5:  Loss= 0.0083, Accuracy= 0.6190
# Epoch 91, CIFAR-10 Batch 1:  Loss= 0.0079, Accuracy= 0.6208
# Epoch 91, CIFAR-10 Batch 2:  Loss= 0.0051, Accuracy= 0.6256
# Epoch 91, CIFAR-10 Batch 3:  Loss= 0.0027, Accuracy= 0.6250
# Epoch 91, CIFAR-10 Batch 4:  Loss= 0.0048, Accuracy= 0.6248
# Epoch 91, CIFAR-10 Batch 5:  Loss= 0.0070, Accuracy= 0.6122
# Epoch 92, CIFAR-10 Batch 1:  Loss= 0.0048, Accuracy= 0.6244
# Epoch 92, CIFAR-10 Batch 2:  Loss= 0.0055, Accuracy= 0.6208
# Epoch 92, CIFAR-10 Batch 3:  Loss= 0.0080, Accuracy= 0.6228
# Epoch 92, CIFAR-10 Batch 4:  Loss= 0.0062, Accuracy= 0.6248
# Epoch 92, CIFAR-10 Batch 5:  Loss= 0.0086, Accuracy= 0.6192
# Epoch 93, CIFAR-10 Batch 1:  Loss= 0.0066, Accuracy= 0.6164
# Epoch 93, CIFAR-10 Batch 2:  Loss= 0.0070, Accuracy= 0.6174
# Epoch 93, CIFAR-10 Batch 3:  Loss= 0.0045, Accuracy= 0.6270
# Epoch 93, CIFAR-10 Batch 4:  Loss= 0.0038, Accuracy= 0.6250
# Epoch 93, CIFAR-10 Batch 5:  Loss= 0.0081, Accuracy= 0.6300
# Epoch 94, CIFAR-10 Batch 1:  Loss= 0.0163, Accuracy= 0.6210
# Epoch 94, CIFAR-10 Batch 2:  Loss= 0.0049, Accuracy= 0.6238
# Epoch 94, CIFAR-10 Batch 3:  Loss= 0.0026, Accuracy= 0.6290
# Epoch 94, CIFAR-10 Batch 4:  Loss= 0.0091, Accuracy= 0.6216
# Epoch 94, CIFAR-10 Batch 5:  Loss= 0.0077, Accuracy= 0.6242
# Epoch 95, CIFAR-10 Batch 1:  Loss= 0.0085, Accuracy= 0.6298
# Epoch 95, CIFAR-10 Batch 2:  Loss= 0.0055, Accuracy= 0.6242
# Epoch 95, CIFAR-10 Batch 3:  Loss= 0.0030, Accuracy= 0.6302
# Epoch 95, CIFAR-10 Batch 4:  Loss= 0.0051, Accuracy= 0.6220
# Epoch 95, CIFAR-10 Batch 5:  Loss= 0.0053, Accuracy= 0.6254
# Epoch 96, CIFAR-10 Batch 1:  Loss= 0.0109, Accuracy= 0.6064
# Epoch 96, CIFAR-10 Batch 2:  Loss= 0.0043, Accuracy= 0.6238
# Epoch 96, CIFAR-10 Batch 3:  Loss= 0.0046, Accuracy= 0.6258
# Epoch 96, CIFAR-10 Batch 4:  Loss= 0.0048, Accuracy= 0.6172
# Epoch 96, CIFAR-10 Batch 5:  Loss= 0.0091, Accuracy= 0.6264
# Epoch 97, CIFAR-10 Batch 1:  Loss= 0.0090, Accuracy= 0.6170
# Epoch 97, CIFAR-10 Batch 2:  Loss= 0.0082, Accuracy= 0.6226
# Epoch 97, CIFAR-10 Batch 3:  Loss= 0.0055, Accuracy= 0.6236
# Epoch 97, CIFAR-10 Batch 4:  Loss= 0.0030, Accuracy= 0.6258
# Epoch 97, CIFAR-10 Batch 5:  Loss= 0.0106, Accuracy= 0.6170
# Epoch 98, CIFAR-10 Batch 1:  Loss= 0.0073, Accuracy= 0.6206
# Epoch 98, CIFAR-10 Batch 2:  Loss= 0.0068, Accuracy= 0.6178
# Epoch 98, CIFAR-10 Batch 3:  Loss= 0.0057, Accuracy= 0.6248
# Epoch 98, CIFAR-10 Batch 4:  Loss= 0.0038, Accuracy= 0.6300
# Epoch 98, CIFAR-10 Batch 5:  Loss= 0.0065, Accuracy= 0.6272
# Epoch 99, CIFAR-10 Batch 1:  Loss= 0.0052, Accuracy= 0.6224
# Epoch 99, CIFAR-10 Batch 2:  Loss= 0.0083, Accuracy= 0.6118
# Epoch 99, CIFAR-10 Batch 3:  Loss= 0.0058, Accuracy= 0.6260
# Epoch 99, CIFAR-10 Batch 4:  Loss= 0.0048, Accuracy= 0.6250
# Epoch 99, CIFAR-10 Batch 5:  Loss= 0.0054, Accuracy= 0.6204
# Epoch 100, CIFAR-10 Batch 1:  Loss= 0.0036, Accuracy= 0.6178
# Epoch 100, CIFAR-10 Batch 2:  Loss= 0.0178, Accuracy= 0.6074
# Epoch 100, CIFAR-10 Batch 3:  Loss= 0.0132, Accuracy= 0.6200
# Epoch 100, CIFAR-10 Batch 4:  Loss= 0.0081, Accuracy= 0.6208
# Epoch 100, CIFAR-10 Batch 5:  Loss= 0.0063, Accuracy= 0.6148

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.6125344663858414

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
